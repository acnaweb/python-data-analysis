# %%
filename = "datasets/pima-data.csv"

# %%
cols = ["preg", "plas", "pres", "skin", "test", "mass", "pedi", "age", "classe"]

# %%
# metodo 1
import pandas as pd
df  = pd.read_csv(filename, names = cols)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  classe
# 0     6   148    72    35     0  33.6  0.627   50       1
# 1     1    85    66    29     0  26.6  0.351   31       0
# 2     8   183    64     0     0  23.3  0.672   32       1
# 3     1    89    66    23    94  28.1  0.167   21       0
# 4     0   137    40    35   168  43.1  2.288   33       1

# %%
#metodo 2
from pandas import read_csv
df = read_csv(filename, names = cols)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  classe
# 0     6   148    72    35     0  33.6  0.627   50       1
# 1     1    85    66    29     0  26.6  0.351   31       0
# 2     8   183    64     0     0  23.3  0.672   32       1
# 3     1    89    66    23    94  28.1  0.167   21       0
# 4     0   137    40    35   168  43.1  2.288   33       1

# %%
# salvando os dados 
df.to_pickle("datasets/pima-data.pkl")

# %%
df = pd.read_pickle("datasets/pima-data.pkl")

# %%
df
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  classe
# 0       6   148    72    35     0  33.6  0.627   50       1
# 1       1    85    66    29     0  26.6  0.351   31       0
# 2       8   183    64     0     0  23.3  0.672   32       1
# 3       1    89    66    23    94  28.1  0.167   21       0
# 4       0   137    40    35   168  43.1  2.288   33       1
# ..    ...   ...   ...   ...   ...   ...    ...  ...     ...
# 763    10   101    76    48   180  32.9  0.171   63       0
# 764     2   122    70    27     0  36.8  0.340   27       0
# 765     5   121    72    23   112  26.2  0.245   30       0
# 766     1   126    60     0     0  30.1  0.349   47       1
# 767     1    93    70    31     0  30.4  0.315   23       0
#
# [768 rows x 9 columns]

# %%
# formato intercambeavel com R
df.to_feather("datasets/pima-data.ft")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-67e731ae516f> in <module>
#       1 # formato intercambeavel com R
# ----> 2 df.to_feather("datasets/pima-data.ft")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in to_feather(self, path, **kwargs)
#    2213         from pandas.io.feather_format import to_feather
#    2214
# -> 2215         to_feather(self, path, **kwargs)
#    2216
#    2217     @doc(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/feather_format.py in to_feather(df, path, **kwargs)
#      21         .. versionadded:: 1.1.0
# ...
