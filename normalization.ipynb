# %%
import sys
sys.path.append("lib")
import geradados

# %%
df = geradados.get_raw_data()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_norm = df.copy()

# %%
df_norm.head()
# Out:
#    riskiness  losses  make fuel type aspiration doors   body drive  \
# 0          2     164  audi       gas        std  four  sedan   fwd
# 1          2     164  audi       gas        std  four  sedan   4wd
# 2          1     158  audi       gas        std  four  sedan   fwd
# 3          1     158  audi       gas      turbo  four  sedan   fwd
# 4          2     192   bmw       gas        std   two  sedan   rwd
#
#   engine location  wheel base  ...  engine size  fuel system  bore  stroke  \
# 0           front        99.8  ...          109         mpfi  3.19     3.4
# 1           front        99.4  ...          136         mpfi  3.19     3.4
# 2           front       105.8  ...          136         mpfi  3.19     3.4
# 3           front       105.8  ...          131         mpfi  3.13     3.4
# 4           front       101.2  ...          108         mpfi  3.50     2.8
#
#   compression ratio horsepower  peak rpm city mpg  highway mpg  price
# ...

# %%
# valores mais altos
geradados.norm_columns(["city mpg", "highway mpg", "horsepower"], df_norm)

# %%
df_norm.head()
# Out:
#    riskiness  losses  make fuel type aspiration doors   body drive  \
# 0          2     164  audi       gas        std  four  sedan   fwd
# 1          2     164  audi       gas        std  four  sedan   4wd
# 2          1     158  audi       gas        std  four  sedan   fwd
# 3          1     158  audi       gas      turbo  four  sedan   fwd
# 4          2     192   bmw       gas        std   two  sedan   rwd
#
#   engine location  wheel base  ...  engine size  fuel system  bore  stroke  \
# 0           front        99.8  ...          109         mpfi  3.19     3.4
# 1           front        99.4  ...          136         mpfi  3.19     3.4
# 2           front       105.8  ...          136         mpfi  3.19     3.4
# 3           front       105.8  ...          131         mpfi  3.13     3.4
# 4           front       101.2  ...          108         mpfi  3.50     2.8
#
#   compression ratio horsepower  peak rpm  city mpg  highway mpg  price
# ...

# %%
# valores mais baixo
geradados.invert_norm_columns(["price", "weight", "riskiness", "losses"], df_norm)

# %%
df_norm.head()
# Out:
#    riskiness    losses  make fuel type aspiration doors   body drive  \
# 0        0.2  0.481675  audi       gas        std  four  sedan   fwd
# 1        0.2  0.481675  audi       gas        std  four  sedan   4wd
# 2        0.4  0.513089  audi       gas        std  four  sedan   fwd
# 3        0.4  0.513089  audi       gas      turbo  four  sedan   fwd
# 4        0.2  0.335079   bmw       gas        std   two  sedan   rwd
#
#   engine location  wheel base  ...  engine size  fuel system  bore  stroke  \
# 0           front        99.8  ...          109         mpfi  3.19     3.4
# 1           front        99.4  ...          136         mpfi  3.19     3.4
# 2           front       105.8  ...          136         mpfi  3.19     3.4
# 3           front       105.8  ...          131         mpfi  3.13     3.4
# 4           front       101.2  ...          108         mpfi  3.50     2.8
#
#   compression ratio horsepower  peak rpm  city mpg  highway mpg     price
# ...

# %%
df_norm.to_pickle("data/df_cars_norm.pkl")
